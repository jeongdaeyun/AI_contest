# %%
import torch

DEVICE = torch.device('mps:0' if torch.backends.mps.is_available() else 'cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"your device: {DEVICE}")

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model.to(DEVICE)

imgs = ['./data/temp/temp1.jpeg']

results = model(imgs)

# results.print()
results.show()

# results.xyxy[0] # tensor
results.pandas().xyxy[0] # pandas
# Out:
# Using cache found in /Users/junsun/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-9-7 Python-3.11.5 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# your device: mps:0
# image 1/1: 410x730 7 persons
# Speed: 5.6ms pre-process, 38.7ms inference, 5.5ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=730x410>
#          xmin        ymin        xmax        ymax  confidence  class    name
# 0  272.480682   23.552647  443.982391  409.969543    0.925068      0  person
# 1  453.224609   74.698357  625.375732  406.774567    0.870480      0  person
# 2   -0.280022    5.723801  334.859985  411.120605    0.813650      0  person
# 3  468.774170  120.299286  504.884308  186.717957    0.736173      0  person
# 4  539.397949   22.116266  689.785706  377.304169    0.666666      0  person
# 5  643.157837  120.933884  697.371338  345.898773    0.626018      0  person
# 6  656.996033  128.370163  691.875061  256.777649    0.345730      0  person
